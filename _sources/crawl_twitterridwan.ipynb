# %% [markdown]
# # Crawling Twitter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/prosaindata
# Out:
# /content/drive/MyDrive/prosaindata

# %%
# !pip install snscrape
# !pip install tqdm 
# !pip install ipywidgets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 2.4 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.0 MB/s eta 0:00:00
# ...

# %%
from tqdm.notebook import tqdm
from ipywidgets import FloatProgress
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
scraper=sntwitter.TwitterSearchScraper("ridwan kamil")
tweets=[]
n_tweets=500
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
    data=[
        tweet.user.username, 
        tweet.rawContent, 
        tweet.user.location,
    ]
    tweets.append(data)
    if i > n_tweets:
        break
tweet_df=pd.DataFrame(tweets, columns=['@Username','Tweet', 'Lokasi'])
tweet_df
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#          @Username                                              Tweet  \
# 0     HitamMetaIik  @humasjabar @ridwankamil @ESDMJabar Siap si pa...
# 1        masnunano  @PaUuRuzhanul @ridwankamil @humasjabar Bagus p...
# 2          SidVanz  @humasjabar @ridwankamil @ESDMJabar Buat commu...
# 3        Ridwan_RN  @humasjabar @ridwankamil Kang rek puasa mah, p...
# 4       humasjabar  "Menjelang Ramadhan di Area #MasjidRayaAlJabba...
# ..             ...                                                ...
# 497    robbyiborrn  @edwinbazz @humasjabar @zenibayusukma @ridwank...
# 498       misuqie8  @RESTABES_BDG @txtdaribandung @GedebagePolsek ...
# 499  NiaRamasteril  MESJID AL JABAR DI TUTUP, BEGINI KATA RIDWAN K...
# 500     infocisels  @PRFMnews Niatnya bagus, yang layak Dan harus ...
# 501      longcatzz  @humasjabar @elkhoers_ID @ridwankamil @ESDMJab...
#
#                             Lokasi
# 0                             JAWA
# 1
# 2
# ...

# %%
data=tweet_df.to_csv("/content/drive/MyDrive/prosaindata/tugas/'data_twitter_ridwankamil.csv'", index=False)

# %%
show_csv = pd.read_csv("/content/drive/MyDrive/prosaindata/tugas/'data_twitter_ridwankamil.csv'")
show_csv
# Out:
#          @Username                                              Tweet  \
# 0     HitamMetaIik  @humasjabar @ridwankamil @ESDMJabar Siap si pa...
# 1        masnunano  @PaUuRuzhanul @ridwankamil @humasjabar Bagus p...
# 2          SidVanz  @humasjabar @ridwankamil @ESDMJabar Buat commu...
# 3        Ridwan_RN  @humasjabar @ridwankamil Kang rek puasa mah, p...
# 4       humasjabar  "Menjelang Ramadhan di Area #MasjidRayaAlJabba...
# ..             ...                                                ...
# 497    robbyiborrn  @edwinbazz @humasjabar @zenibayusukma @ridwank...
# 498       misuqie8  @RESTABES_BDG @txtdaribandung @GedebagePolsek ...
# 499  NiaRamasteril  MESJID AL JABAR DI TUTUP, BEGINI KATA RIDWAN K...
# 500     infocisels  @PRFMnews Niatnya bagus, yang layak Dan harus ...
# 501      longcatzz  @humasjabar @elkhoers_ID @ridwankamil @ESDMJab...
#
#                             Lokasi
# 0                             JAWA
# 1                              NaN
# ...
